# %%
import pandas as pd

# %%
df_recipes = pd.read_csv('Dataset Foodboost/recipes.csv')

# Drop de onnodige kolommen
df_recipes.drop([ 'Unnamed: 0', 'persons','time','calories','stars','url','image'], axis = 1, inplace = True)

# 200 Willekeurige recepten selecteren
df_recipes_lekker = df_recipes.sample(n=200)

# Deze recepten 1 keer gerund en deze 200 geprint om vervolgend handmatig aan te geven of ik die wel of niet lekker vind.
for i in range (300):
    
    random_recept = df_recipes_lekker.iloc[i]
    random_recept[0]
    print("'" + random_recept[0] + "'" + ': ' + " ,")
# Out:
# 'Tomatensoep met steak tartaarburger':  ,
# 'Geroosterde aardappelen met aïoli-yoghurtdressing':  ,
# 'Focaccia uit de airfryer':  ,
# 'Empanadas met kip':  ,
# 'Tagliatelle met veggie balls in tomatensaus':  ,
# 'Varkensfiletrollade met salie en lardo':  ,
# 'Zalm met venkel, sinaasappel en verse kruiden':  ,
# 'Hertenbief met paddenstoelen en pastinaakpuree':  ,
# 'Teriyaki-honingkipspiesjes met groenteroerbak':  ,
# 'Biefstukspiesen met gestoofde paprika en oregano':  ,
# 'Rosbief in saliesaus met appel en geroosterde groenten ':  ,
# 'Geroosterde pompoen-linzensalade met venkel &amp; ricotta':  ,
# 'Visburgers':  ,
# 'Ananascrumble met kokos en limoen':  ,
# 'Gele rijst met salami en puntpaprika ':  ,
# 'Broodje milanese met parrano snippers':  ,
# 'Curry madras met vis en linzenrijst':  ,
# 'Noedelsoep':  ,
# 'Eton mess met rabarber':  ,
# 'Kokos-chocotaart':  ,
# 'Key lime pie':  ,
# 'Jonas Cramby's nacho de nachos (maistortillas met entrecote)':  ,
# 'Truffel-eiersalade met avocado':  ,
# 'Pappardelle met ricotta en gepofte snoeptomaten':  ,
# 'Zomerstoof met ratatouille en chipolata':  ,
# 'Bladerdeeghapje met zalm en spinazie':  ,
# 'Koreaanse burgertjes':  ,
# 'Rijstsalade met kaassnippers':  ,
# 'Mediterrane quinoasalade':  ,
# 'Cherrytomaten met bonen':  ,
# 'Kruidendip met cottagecheese':  ,
# 'Cranberrytiramisu':  ,
# 'Boerenkoolstamppot met pastinaak en een gehaktbal':  ,
# 'Rijstsalade met omeletreepjes en basilicumolie':  ,
# 'Ovengeroosterde pastinaak met aioli':  ,
# 'Koffie milkshake':  ,
# 'Kleurrijke glutenvrije pennesalade':  ,
# 'Auberginerolletjes in tomatensaus':  ,
# 'Soezentaart':  ,
# 'Zoete bliksem met appel en spek ':  ,
# 'Kruidnoten + 3 kruidnoten variaties':  ,
# 'Visburgers met aardappel, bloemkool en harissa':  ,
# 'Pizza chorizo en cannellinibonen':  ,
# 'Rollade met tomatensaus':  ,
# 'Ovenschotel bloemkool &amp; kaas':  ,
# 'Megakruidnoottruffels ':  ,
# 'Aardappelsalade met bacon':  ,
# 'Noedelsoep met chinese kool en tempé':  ,
# 'Old fashioned':  ,
# 'Knoflookballetjes met satésaus':  ,
# 'Vegetarische pasta met tomatensaus en mozzarella':  ,
# 'Italiaanse eendenborst met tomaatjes en lasagnette':  ,
# 'Roerbakrijst met kipfilet en basilicum':  ,
# 'Knolselderijgratin met appel en walnoten':  ,
# 'Burger met avocado en gebakken ei':  ,
# 'Karbonade, aardappeltjes en rodekool-rozijnensalade':  ,
# 'Superbowl van snackgroenten met bagna cauda-dip':  ,
# 'Appel-perencompote':  ,
# 'Twix-brownietaart met karamelpopcorn':  ,
# 'Mayonaise met ei en mosterd':  ,
# 'Havermoutpannenkoeken met banaan en kaneel':  ,
# 'Saté babi van de bbq':  ,
# 'Lemon curd taartje met sinaasappel en blauwe bessen':  ,
# 'Aardbeien uit oven met roomyoghurt':  ,
# 'Spicy Latin hotdog':  ,
# 'Rijstsalade met tonijn en olijven':  ,
# 'Bulgogi':  ,
# 'Slagroomtaart met roos':  ,
# 'Prei-tuinerwtensoep met basilicum':  ,
# 'Krieltjes in de schil met steak de boeuf en sperziebonen':  ,
# 'Rozijnenpannenkoekjes met lemon curd':  ,
# 'Pittige ovenaardappelen met dips':  ,
# 'Quinoa met gegrilde avocado en granaatappel':  ,
# 'Rijstnoedels met gehakt en champignons':  ,
# 'Gepofte knoflooksoep met chorizo-olie':  ,
# 'Yotam Ottolenghi's geroosterde aubergines':  ,
# 'Zoete aardappel met blauwe-kaassaus en kip':  ,
# 'Courgetti met vegaballetjes &amp; tomaat':  ,
# 'Platbrood en avocadopuree met tahin en olijven':  ,
# 'Panettone':  ,
# 'Lasagne met salami &amp; mozzarella':  ,
# 'Kleine mango-kipsalade':  ,
# 'Chocolade-empanadas met banaan en kokos ':  ,
# 'Pasta met rode saus':  ,
# 'Minifrittata met chorizo en courgette':  ,
# 'Blanco de verano-sorbet':  ,
# 'Massaman curry':  ,
# 'Speculaas-suikerbollenwentelteefjes':  ,
# 'Komkommer-radijsgazpacho':  ,
# 'Groenteomelet met gegrilde makreel':  ,
# 'Tagliatelle met zalm':  ,
# 'Kruidige curry met kip, zoete aardappel en boontjes':  ,
# 'Zoetzure paprikasalade':  ,
# 'Gebakken aardappeltjes met worst en sla':  ,
# 'Bietentagliatelle met basilicum ':  ,
# 'Tagliatelle met paprikasaus, venkel en garnalen':  ,
# 'Mihoen met zoetzure garnalen':  ,
# 'Snelle bouillabaisse met croutons':  ,
# 'Zalm met bladerdeeg en dillerijst':  ,
# 'Rijstsalade met zwarte bonen':  ,
# 'Gekaramelliseerde pecannoten met honing':  ,
# 'Tom kha kai':  ,
# 'Broccoli-spinaziesoep en toast met kip en avocado':  ,
# 'Kabeljauwburger met prei, ovenaardappeltjes en witlofsalade':  ,
# 'Thaise kippasteitjes':  ,
# 'Hartige taart met zwarte knoflook':  ,
# 'Shanghai paksoi met shiitake en bosui ':  ,
# 'Warme brownies met cookie dough ijs':  ,
# 'Krokante avocadofrieten met salsa van Jaimie van Heije':  ,
# 'Coq-au-vin op spies':  ,
# 'Selderijremoulade met gerookte forel':  ,
# 'Notenquiche':  ,
# 'Glutenvrije gevulde speculaas':  ,
# 'Goedgevulde tomaten-groentesoep met rookworst':  ,
# 'Indiase sandwich gebakken kip met eisalade':  ,
# 'Spaanse bonenschotel met vis':  ,
# 'Plaattaart met gegrilde groenten':  ,
# 'Pompoen-wortelsoep met naan':  ,
# 'Zomerse risotto met een zachtgekookt eitje ':  ,
# 'Pasta met kipgehakt, spinazie &amp; tomatensaus':  ,
# 'Aardappelgratin met zoete ui':  ,
# 'Mediterrane boerenkoolstamp':  ,
# 'Limoenkipsaté met olijvenmayonaise':  ,
# 'Ovenchili':  ,
# 'Linzensoep met pompoen &amp; komijn ':  ,
# 'Gebakken gnocchi met gegrilde groenten en mozzarella':  ,
# 'Rijkgevulde groentebowl met tonijn &amp; pittige dressing':  ,
# 'Pizza bianca met spek, ricotta &amp; provolone':  ,
# 'Andijviestamppot met groenteballetjes':  ,
# 'Gegratineerde kalkoenrolletjes':  ,
# 'Steak tartaar ':  ,
# 'Pita vega gyros met rauwkost &amp; tzatziki':  ,
# 'Groenten met laurier, kruidnagel en peper op zuur':  ,
# 'Mangosmoothie met kokos':  ,
# 'Mediterrane campingpasta':  ,
# 'Kokos-vanilleroomijs':  ,
# 'Tofu roerbak met broccoli, champignons &amp; sojasaus':  ,
# 'Frisse tonijn-radijssalade met sperziebonen en geroosterde walnoten':  ,
# 'Pasta alla pizzaiola met malse kipgehaktballetjes':  ,
# 'Pasta met parmaham':  ,
# 'Pasta met ratatouille en gebakken ricotta':  ,
# 'Dave Myers &amp; Si King's omelet met doperwten, munt en feta':  ,
# 'Griekse salade met yoghurtdressing':  ,
# 'Glutenvrije blini's':  ,
# 'Varkensreepjes in pikante saus':  ,
# 'Pompoen met geitenkaas en munt':  ,
# 'Mueslirepen met honing en cranberry's':  ,
# 'Oosterse filetlapjes en komkommer':  ,
# 'Kruidenquiche met ham en prei':  ,
# 'Avocado Bounty van Fooddeco':  ,
# 'Roerei met kiemgroente &amp; volkorentoast':  ,
# 'Rijst met kabeljauw en chipotlesaus':  ,
# 'Burrito met gebakken linzen &amp; romige spitskoolsalade':  ,
# 'Tomaten-paprikasoep met balletjes':  ,
# 'Meloensalade met geitenkaas':  ,
# 'Cevapcici (worstjes uit de balkan)':  ,
# 'Scones met citroenroomkaas &amp; smoothie':  ,
# 'Zoete uienpizza':  ,
# 'Sticky barbecuebeenham':  ,
# 'Chinese eiermie met snijbonen en kipgehakt':  ,
# 'Aziatische kipballetjes met wortelrijst':  ,
# 'Gevulde pompoenrollade':  ,
# 'Appel-meloensap':  ,
# 'Zalige vispastei met erwten':  ,
# 'Preibroodjes met oude kaas en mosterd':  ,
# 'Tomatensoep met garnalen en kikkererwten':  ,
# 'Minipizza's met salami of zalm ':  ,
# 'Honing-kaneelkwark in een glaasje':  ,
# 'Gezonde kerstboombroodjes':  ,
# 'Stamppot rodekool met tutti frutti':  ,
# 'IJssandwich met choc-chipcookies':  ,
# 'Tomatenrisotto met gegrilde tomaatjes, amandelen &amp; basilicum':  ,
# 'Zoete-aardappelpuree van de BBQ met ahornsiroop en pecannoten':  ,
# 'Lamsworstjes met salsa verde en groene couscous':  ,
# 'Wraps met gegrilde biefstuk':  ,
# 'Volkorenpasta met zoete-aardappelspaghetti':  ,
# 'Snelle chili sin carne met guacamole, bloemkoolrijst en gegrilde paprika':  ,
# 'Couscous met worstjes':  ,
# 'Naan met zalm in sojasaus &amp; sojabonenspread':  ,
# 'Ribkarbonades met rozemarijn':  ,
# 'Meatloaf met verstopte eieren':  ,
# 'Ovenschotel met gehakt en spitskool':  ,
# 'Grand dessert ':  ,
# 'Gebakken sliptong met zelfgemaakt visspecerijenzout':  ,
# 'Hutspot, yoghurt en koriander':  ,
# 'Lofsalade met gerookte eendenborst':  ,
# 'Vegan pannenkoeken':  ,
# 'Martini Bianco met tonic':  ,
# 'Urumaki sushi (inside out roll)':  ,
# 'Romige kip met broccoli, prei en rijst':  ,
# 'Pilav van zilvervliesrijst met tonijn, tomaat en aubergine':  ,
# 'Beefburger met hummus en spinazie':  ,
# 'Gegrilde-courgettesalade met rozemarijnolie en gorgonzola':  ,
# 'Zomerse bonen-preistoof met gegrilde ricotta en tomatensaus':  ,
# 'Volkorenhavermout met banaan, amandel en kokos':  ,
# 'Volkorenpastasalade met mozzarellabolletjes, sojabonen, tonijn en komkommer':  ,
# 'Kikkererwtenstoof met kokosmelk, kurkuma en spinazie ('the stew')':  ,
# 'Rappe caesar salad met tonijn-mayosaus':  ,
# 'Harira met harissa':  ,
# 'Puree met spinazie en ricotta':  ,
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [5], line 12
#       9 # Deze recepten 1 keer gerund en deze 200 geprint om vervolgend handmatig aan te geven of ik die wel of niet lekker vind.
#      10 for i in range (300):
# ---> 12     random_recept = df_recipes_lekker.iloc[i]
#      13     random_recept[0]
#      14     print("'" + random_recept[0] + "'" + ': ' + " ,")
#
# File /opt/jupyterhub/anaconda/lib/python3.9/site-packages/pandas/core/indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File /opt/jupyterhub/anaconda/lib/python3.9/site-packages/pandas/core/indexing.py:1523, in _iLocIndexer._getitem_axis(self, key, axis)
#    1520     raise TypeError("Cannot index by location index with a non-integer key")
#    1522 # validate the location
# -> 1523 self._validate_integer(key, axis)
#    1525 return self.obj._ixs(key, axis=axis)
#
# File /opt/jupyterhub/anaconda/lib/python3.9/site-packages/pandas/core/indexing.py:1455, in _iLocIndexer._validate_integer(self, key, axis)
#    1453 len_axis = len(self.obj._get_axis(axis))
#    1454 if key >= len_axis or key < -len_axis:
# -> 1455     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds
